# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import math
import seaborn as sns

custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params); np.random.seed(0)
# %matplotlib inline
tqdm.pandas()

import warnings
warnings.filterwarnings('ignore')

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# # Load & Pre-process dataset

# %%
bg_access = pd.read_csv('../data/bg_fp_regression.csv', dtype={'bg_fips':str, 'bg_county':str})
bg_access
# Out:
#              bg_fips                               address  distance_mi
# 0       010010201001  203 N Court St, Prattville, AL 36067     0.835864  \
# 1       010010201002  203 N Court St, Prattville, AL 36067     1.684913
# 2       010010202001  203 N Court St, Prattville, AL 36067     1.065305
# 3       010010202002  203 N Court St, Prattville, AL 36067     0.327409
# 4       010010203001  203 N Court St, Prattville, AL 36067     1.367486
# ...              ...                                   ...          ...
# 239775  560430002003                                   NaN          NaN
# 239776  560459511002                                   NaN          NaN
# 239777  560459513001                                   NaN          NaN
# 239778  560459513002                                   NaN          NaN
# 239779  560459513003                                   NaN          NaN
#
#         transit_time  walking_time  ADI_NATRANK ADI_STATERNK bg_state
# 0              20.08         20.08         73.0            5       AL  \
# 1              37.30         37.30         62.0            3       AL
# 2              20.33         20.33         83.0            7       AL
# 3               8.40          8.40         87.0            7       AL
# 4              42.63         42.63         73.0            5       AL
# ...              ...           ...          ...          ...      ...
# 239775           NaN           NaN         47.0            5       WY
# 239776           NaN           NaN         49.0            6       WY
# 239777           NaN           NaN         85.0           10       WY
# 239778           NaN           NaN         70.0            9       WY
# 239779           NaN           NaN         49.0            6       WY
#
#        bg_county    status  access
# 0          01001     Metro   20.08
# 1          01001     Metro   37.30
# 2          01001     Metro   20.33
# 3          01001     Metro    8.40
# 4          01001     Metro   42.63
# ...          ...       ...     ...
# 239775     56043  Nonmetro     NaN
# 239776     56045  Nonmetro     NaN
# 239777     56045  Nonmetro     NaN
# 239778     56045  Nonmetro     NaN
# 239779     56045  Nonmetro     NaN
#
# [239780 rows x 11 columns]

# %%
bg_access.describe()
# Out:
#          distance_mi   transit_time   walking_time    ADI_NATRANK
# count  238536.000000  166589.000000  237842.000000  233887.000000  \
# mean        2.566915      28.230644      85.222355      50.115509
# std         3.181968      29.585616     371.591318      28.741300
# min         0.000197       0.000000       0.000000       1.000000
# 25%         0.681729      13.280000      19.980000      25.000000
# 50%         1.435726      23.600000      42.350000      50.000000
# 75%         3.074115      38.500000      90.430000      75.000000
# max        24.990148    2631.880000   28848.120000     100.000000
#
#               access
# count  237934.000000
# mean       78.712034
# std       336.442417
# min         0.000000
# 25%        17.250000
# 50%        35.220000
# 75%        80.480000
# max     28848.120000

# %% [markdown]
# # 1. Linear Regression

# %% [markdown]
# ## (1) ~ ADI

# %% [markdown]
# - The coefficient: 0.611
#     - If ADI increases (more disadvantaged), then time increases (less accessibility) by transit or walk.

# %%
adi_lm = smf.glm(formula = "access ~ ADI_NATRANK", data=bg_access)
adi_res = adi_lm.fit()
adi_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 access   No. Observations:               232337
# Model:                            GLM   Df Residuals:                   232335
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               Identity   Scale:                      1.1394e+05
# Method:                          IRLS   Log-Likelihood:            -1.6823e+06
# Date:                Fri, 19 May 2023   Deviance:                   2.6473e+10
# Time:                        21:28:35   Pearson chi2:                 2.65e+10
# No. Iterations:                     3   Pseudo R-squ. (CS):           0.002697
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      48.0173      1.406     34.145      0.000      45.261      50.773
# ADI_NATRANK     0.6106      0.024     25.047      0.000       0.563       0.658
# ===============================================================================
# """

# %% [markdown]
# ## (2) ~ ADI + Rural

# %%
adi_rural_lm = smf.glm(formula = "access ~ ADI_NATRANK + C(status)", data=bg_access)
adi_rural_res = adi_rural_lm.fit()
adi_rural_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 access   No. Observations:               232336
# Model:                            GLM   Df Residuals:                   232333
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               Identity   Scale:                      1.1236e+05
# Method:                          IRLS   Log-Likelihood:            -1.6806e+06
# Date:                Fri, 19 May 2023   Deviance:                   2.6106e+10
# Time:                        21:28:58   Pearson chi2:                 2.61e+10
# No. Iterations:                     3   Pseudo R-squ. (CS):            0.01664
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                53.4745      1.400     38.203      0.000      50.731      56.218
# C(status)[T.Nonmetro]   112.7195      1.974     57.110      0.000     108.851     116.588
# ADI_NATRANK               0.1237      0.026      4.821      0.000       0.073       0.174
# =========================================================================================
# """
