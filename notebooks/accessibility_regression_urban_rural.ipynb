# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import math
import seaborn as sns

custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params); np.random.seed(0)
# %matplotlib inline
tqdm.pandas()

import warnings
warnings.filterwarnings('ignore')

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# # Load & Pre-process dataset

# %%
metro_bg_access = pd.read_csv('../data/metro_fp_regression.csv',dtype={'bg_fips':str, 'bg_county':str})
metro_bg_access
# Out:
#              bg_fips                                        address  \
# 0       040130405022     360 W. Yavapai Street Wickenburg, AZ 85390
# 1       040130405024     360 W. Yavapai Street Wickenburg, AZ 85390
# 2       040159501021    280 W Township Ave, Colorado City, AZ 86021
# 3       050690010001             500 S Main St Pine Bluff, AR 71601
# 4       120210111071  101 S Copeland Ave, Everglades City, FL 34139
# ...              ...                                            ...
# 198762  560250016031      4301 Casper Mountain Rd, Casper, WY 82601
# 198763  560250017003        4250 Poison Spider Road MIlls, WY 82644
# 198764  560250018011              411 S. Walsh Dr. Casper, WY 82609
# 198765  560250018012      4301 Casper Mountain Rd, Casper, WY 82601
# 198766  560250018022                 4976 Paige St Casper, WY 82604
#
#         distance_mi  transit_time  walking_time driving_distance_km  \
# 0          0.540367           NaN     14.700000               1.285
# 1          0.188818           NaN      5.830000               0.482
# 2          1.230661           NaN      8.500000               0.774
# 3          0.236860           NaN      6.083333               0.474
# 4          0.611384           NaN      8.230000               1.464
# ...             ...           ...           ...                 ...
# 198762     2.872862           NaN     95.750000                7.84
# 198763     4.112575           NaN    106.980000               9.361
# 198764     7.722157           NaN    169.970000              30.529
# 198765    15.406593           NaN    539.400000              55.932
# 198766     7.753469           NaN    168.950000              14.633
#
#         ADI_NATRANK ADI_STATERNK bg_state bg_county status      access  \
# 0              40.0            4       AZ     04013  Metro   14.700000
# 1              64.0            7       AZ     04013  Metro    5.830000
# 2              67.0            8       AZ     04015  Metro    8.500000
# 3               NaN           GQ       AR     05069  Metro    6.083333
# 4              54.0            6       FL     12021  Metro    8.230000
# ...             ...          ...      ...       ...    ...         ...
# 198762         23.0            1       WY     56025  Metro   95.750000
# 198763         39.0            4       WY     56025  Metro  106.980000
# 198764         18.0            1       WY     56025  Metro  169.970000
# 198765         18.0            1       WY     56025  Metro  539.400000
# 198766         28.0            2       WY     56025  Metro  168.950000
#
#            category
# 0       High access
# 1       High access
# 2       High access
# 3       High access
# 4       High access
# ...             ...
# 198762   Low access
# 198763   Low access
# 198764   Low access
# 198765   Low access
# 198766   Low access
#
# [198767 rows x 13 columns]

# %%
metro_bg_access.describe()
# Out:
#          distance_mi   transit_time   walking_time    ADI_NATRANK  \
# count  198579.000000  153558.000000  198068.000000  193841.000000
# mean        2.011049      28.131101      66.696565      45.748691
# std         2.290210      29.577986     303.883043      28.246172
# min         0.000197       0.000000       0.000000       1.000000
# 25%         0.629761      13.180000      18.550000      21.000000
# 50%         1.278648      23.430000      37.920000      43.000000
# 75%         2.498006      38.270000      74.220000      69.000000
# max        24.971662    2631.880000   28824.680000     100.000000
#
#               access
# count  198153.000000
# mean       59.302310
# std       249.845871
# min         0.000000
# 25%        15.950000
# 50%        31.050000
# 75%        61.670000
# max     28783.730000

# %%
df = pd.read_csv("../data/nhgis0001_ds258_2020_blck_grp.csv", encoding='ISO-8859-1', dtype={'GEOCODE':str})
print(df)
# Out:
#                 GISJOIN  YEAR STUSAB                  GEOID       GEOCODE  \
# 0       G01000100201001  2020     AL  1500000US010010201001  010010201001
# 1       G01000100201002  2020     AL  1500000US010010201002  010010201002
# 2       G01000100202001  2020     AL  1500000US010010202001  010010202001
# 3       G01000100202002  2020     AL  1500000US010010202002  010010202002
# 4       G01000100203001  2020     AL  1500000US010010203001  010010203001
# ...                 ...   ...    ...                    ...           ...
# 242330  G72015307506011  2020     PR  1500000US721537506011  721537506011
# 242331  G72015307506012  2020     PR  1500000US721537506012  721537506012
# 242332  G72015307506013  2020     PR  1500000US721537506013  721537506013
# 242333  G72015307506021  2020     PR  1500000US721537506021  721537506021
# 242334  G72015307506022  2020     PR  1500000US721537506022  721537506022
#
#         REGIONA  DIVISIONA        STATE  STATEA           COUNTY  ...  \
# 0             3          6      Alabama       1   Autauga County  ...
# 1             3          6      Alabama       1   Autauga County  ...
# 2             3          6      Alabama       1   Autauga County  ...
# 3             3          6      Alabama       1   Autauga County  ...
# 4             3          6      Alabama       1   Autauga County  ...
# ...         ...        ...          ...     ...              ...  ...
# 242330        9          0  Puerto Rico      72  Yauco Municipio  ...
# 242331        9          0  Puerto Rico      72  Yauco Municipio  ...
# 242332        9          0  Puerto Rico      72  Yauco Municipio  ...
# 242333        9          0  Puerto Rico      72  Yauco Municipio  ...
# 242334        9          0  Puerto Rico      72  Yauco Municipio  ...
#
#         AREALAND  AREAWATR  BASENAME           NAME  FUNCSTAT   INTPTLAT  \
# 0        4264299     28435         1  Block Group 1         S  32.465832
# 1        5561005         0         2  Block Group 2         S  32.485873
# 2        2058374         0         1  Block Group 1         S  32.480082
# 3        1262444      5669         2  Block Group 2         S  32.464435
# 4        3866513      9054         1  Block Group 1         S  32.480175
# ...          ...       ...       ...            ...       ...        ...
# 242330   9415632      4527         1  Block Group 1         S  18.011049
# 242331    265980         0         2  Block Group 2         S  18.020435
# 242332   1303491         0         3  Block Group 3         S  18.015647
# 242333   1136090      1997         1  Block Group 1         S  18.011872
# 242334  16386327    250956         2  Block Group 2         S  17.971597
#
#          INTPTLON  LSADC  UGA  U7H001
# 0      -86.489661     BG  NaN     575
# 1      -86.489672     BG  NaN    1200
# 2      -86.474974     BG  NaN     974
# 3      -86.469766     BG  NaN    1081
# 4      -86.460792     BG  NaN    2377
# ...           ...    ...  ...     ...
# 242330 -66.839115     BG  NaN    1996
# 242331 -66.844385     BG  NaN     963
# 242332 -66.849913     BG  NaN    1409
# 242333 -66.868938     BG  NaN    1359
# 242334 -66.849851     BG  NaN    1228
#
# [242335 rows x 60 columns]

# %%
bg = df.loc[(~df.GEOCODE.astype(str).str.startswith('72')) ]

# %%
metro_merged =  metro_bg_access.merge(bg, left_on='bg_fips', right_on='GEOCODE', how='left')
print(metro_merged)
# Out:
#              bg_fips                                        address  \
# 0       040130405022     360 W. Yavapai Street Wickenburg, AZ 85390
# 1       040130405024     360 W. Yavapai Street Wickenburg, AZ 85390
# 2       040159501021    280 W Township Ave, Colorado City, AZ 86021
# 3       050690010001             500 S Main St Pine Bluff, AR 71601
# 4       120210111071  101 S Copeland Ave, Everglades City, FL 34139
# ...              ...                                            ...
# 198762  560250016031      4301 Casper Mountain Rd, Casper, WY 82601
# 198763  560250017003        4250 Poison Spider Road MIlls, WY 82644
# 198764  560250018011              411 S. Walsh Dr. Casper, WY 82609
# 198765  560250018012      4301 Casper Mountain Rd, Casper, WY 82601
# 198766  560250018022                 4976 Paige St Casper, WY 82604
#
#         distance_mi  transit_time  walking_time driving_distance_km  \
# 0          0.540367           NaN     14.700000               1.285
# 1          0.188818           NaN      5.830000               0.482
# 2          1.230661           NaN      8.500000               0.774
# 3          0.236860           NaN      6.083333               0.474
# 4          0.611384           NaN      8.230000               1.464
# ...             ...           ...           ...                 ...
# 198762     2.872862           NaN     95.750000                7.84
# 198763     4.112575           NaN    106.980000               9.361
# 198764     7.722157           NaN    169.970000              30.529
# 198765    15.406593           NaN    539.400000              55.932
# 198766     7.753469           NaN    168.950000              14.633
#
#         ADI_NATRANK ADI_STATERNK bg_state bg_county  ...    AREALAND  \
# 0              40.0            4       AZ     04013  ...     1760968
# 1              64.0            7       AZ     04013  ...      689945
# 2              67.0            8       AZ     04015  ...     2915428
# 3               NaN           GQ       AR     05069  ...     1710082
# 4              54.0            6       FL     12021  ...     3091750
# ...             ...          ...      ...       ...  ...         ...
# 198762         23.0            1       WY     56025  ...    23948477
# 198763         39.0            4       WY     56025  ...    11078521
# 198764         18.0            1       WY     56025  ...   119592887
# 198765         18.0            1       WY     56025  ...  1854283320
# 198766         28.0            2       WY     56025  ...   295798615
#
#         AREAWATR BASENAME           NAME  FUNCSTAT   INTPTLAT    INTPTLON  \
# 0              0        2  Block Group 2         S  33.964221 -112.727429
# 1              0        4  Block Group 4         S  33.968560 -112.738904
# 2              0        1  Block Group 1         S  36.994832 -112.981849
# 3              0        1  Block Group 1         S  34.221556  -92.001998
# 4         231144        1  Block Group 1         S  25.849912  -81.389953
# ...          ...      ...            ...       ...        ...         ...
# 198762         0        1  Block Group 1         S  42.796530 -106.385140
# 198763    285816        3  Block Group 3         S  42.808963 -106.443439
# 198764   1094088        1  Block Group 1         S  42.816857 -106.129583
# 198765  17652010        2  Block Group 2         S  42.586221 -106.371572
# 198766   1121202        2  Block Group 2         S  42.848142 -106.543671
#
#        LSADC  UGA  U7H001
# 0         BG  NaN     716
# 1         BG  NaN     746
# 2         BG  NaN    1324
# 3         BG  NaN     826
# 4         BG  NaN     464
# ...      ...  ...     ...
# 198762    BG  NaN    1089
# 198763    BG  NaN    2193
# 198764    BG  NaN     717
# 198765    BG  NaN    1611
# 198766    BG  NaN    1373
#
# [198767 rows x 73 columns]

# %% [markdown]
# # 1. Linear Regression

# %% [markdown]
# ## (1) ~ ADI

# %% [markdown]
# - The coefficient: 0.611
#     - If ADI increases (more disadvantaged), then time increases (less accessibility) by transit or walk.

# %%
metro_adi_lm = smf.glm(formula = "access ~ ADI_NATRANK", data=metro_bg_access)
metro_adi_res = metro_adi_lm.fit()
metro_adi_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 access   No. Observations:               193388
# Model:                            GLM   Df Residuals:                   193386
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                          63007.
# Method:                          IRLS   Log-Likelihood:            -1.3430e+06
# Date:                Wed, 10 Apr 2024   Deviance:                   1.2185e+10
# Time:                        00:55:22   Pearson chi2:                 1.22e+10
# No. Iterations:                     3   Pseudo R-squ. (CS):          0.0001991
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      53.3974      1.087     49.145      0.000      51.268      55.527
# ADI_NATRANK     0.1254      0.020      6.205      0.000       0.086       0.165
# ===============================================================================
# """

# %%
metro_adi_lm2 = smf.glm(formula = "access ~ ADI_NATRANK + AREALAND", data=metro_merged)
metro_adi_res2 = metro_adi_lm2.fit()
metro_adi_res2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 access   No. Observations:               193388
# Model:                            GLM   Df Residuals:                   193385
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                          61761.
# Method:                          IRLS   Log-Likelihood:            -1.3410e+06
# Date:                Wed, 10 Apr 2024   Deviance:                   1.1944e+10
# Time:                        00:55:34   Pearson chi2:                 1.19e+10
# No. Iterations:                     3   Pseudo R-squ. (CS):            0.02018
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      49.9532      1.077     46.376      0.000      47.842      52.064
# ADI_NATRANK     0.0706      0.020      3.525      0.000       0.031       0.110
# AREALAND      5.61e-07   8.98e-09     62.468      0.000    5.43e-07    5.79e-07
# ===============================================================================
# """

# %% [markdown]
# ## (2) ~ ADI + Rural

# %%
rural_bg_access = pd.read_csv('../data/rural_fp_regression.csv', dtype={'bg_fips':str, 'bg_county':str})
rural_bg_access
# Out:
#             bg_fips                                   address  distance_mi  \
# 0      010059501001      111 Jackson Street Eufaula, AL 36072     4.921180
# 1      010059501002      111 Jackson Street Eufaula, AL 36072    11.686954
# 2      010059502001  11 East College Street Clayton, AL 36016     5.718206
# 3      010059502002             276 AL-239, Clayton, AL 36016     4.960451
# 4      010059502003  11 East College Street Clayton, AL 36016     3.365542
# ...             ...                                       ...          ...
# 41008  560430002003                                       NaN          NaN
# 41009  560459511002                                       NaN          NaN
# 41010  560459513001                                       NaN          NaN
# 41011  560459513002                                       NaN          NaN
# 41012  560459513003                                       NaN          NaN
#
#        transit_time  walking_time driving_distance_km  ADI_NATRANK  \
# 0               NaN    126.470000              10.197         76.0
# 1               NaN    272.920000              22.485         94.0
# 2               NaN    117.570000               9.295         95.0
# 3               NaN    147.216667              13.644          NaN
# 4               NaN    105.870000               8.608         90.0
# ...             ...           ...                 ...          ...
# 41008           NaN           NaN              69.685         47.0
# 41009           NaN           NaN              93.009         49.0
# 41010           NaN           NaN              63.563         85.0
# 41011           NaN           NaN               57.73         70.0
# 41012           NaN           NaN              63.628         49.0
#
#       ADI_STATERNK bg_state bg_county    status     access       category
# 0                5       AL     01005  Nonmetro   6.336120    High access
# 1                9       AL     01005  Nonmetro  13.971527  Medium access
# 2                9       AL     01005  Nonmetro   5.775643    High access
# 3               GQ       AL     01005  Nonmetro   8.477986    High access
# 4                8       AL     01005  Nonmetro   5.348762    High access
# ...            ...      ...       ...       ...        ...            ...
# 41008            5       WY     56043  Nonmetro  43.300238     Low access
# 41009            6       WY     56045  Nonmetro  57.793095     Low access
# 41010           10       WY     56045  Nonmetro  39.496205     Low access
# 41011            9       WY     56045  Nonmetro  35.871748     Low access
# 41012            6       WY     56045  Nonmetro  39.536594     Low access
#
# [41013 rows x 13 columns]

# %%
rural_bg_access.describe()
# Out:
#         distance_mi  transit_time  walking_time   ADI_NATRANK        access
# count  39957.000000  13031.000000  39774.000000  40046.000000  40578.000000
# mean       5.329469     29.403673    177.477754     71.252909      9.478568
# std        5.020971     29.651358    596.340135     20.580527     31.025795
# min        0.002277      0.020000      0.020000      1.000000      0.001243
# 25%        1.281108     14.430000     36.070000     58.000000      1.953280
# 50%        3.805173     25.970000    106.940000     75.000000      5.740847
# 75%        7.957177     41.220000    217.565000     88.000000     11.810399
# max       24.990148   1019.630000  28848.120000    100.000000   1535.684251

# %%
rural_merged =  rural_bg_access.merge(bg, left_on='bg_fips', right_on='GEOCODE', how='left')
print(rural_merged)
# Out:
#             bg_fips                                   address  distance_mi  \
# 0      010059501001      111 Jackson Street Eufaula, AL 36072     4.921180
# 1      010059501002      111 Jackson Street Eufaula, AL 36072    11.686954
# 2      010059502001  11 East College Street Clayton, AL 36016     5.718206
# 3      010059502002             276 AL-239, Clayton, AL 36016     4.960451
# 4      010059502003  11 East College Street Clayton, AL 36016     3.365542
# ...             ...                                       ...          ...
# 41008  560430002003                                       NaN          NaN
# 41009  560459511002                                       NaN          NaN
# 41010  560459513001                                       NaN          NaN
# 41011  560459513002                                       NaN          NaN
# 41012  560459513003                                       NaN          NaN
#
#        transit_time  walking_time driving_distance_km  ADI_NATRANK  \
# 0               NaN    126.470000              10.197         76.0
# 1               NaN    272.920000              22.485         94.0
# 2               NaN    117.570000               9.295         95.0
# 3               NaN    147.216667              13.644          NaN
# 4               NaN    105.870000               8.608         90.0
# ...             ...           ...                 ...          ...
# 41008           NaN           NaN              69.685         47.0
# 41009           NaN           NaN              93.009         49.0
# 41010           NaN           NaN              63.563         85.0
# 41011           NaN           NaN               57.73         70.0
# 41012           NaN           NaN              63.628         49.0
#
#       ADI_STATERNK bg_state bg_county  ...    AREALAND  AREAWATR BASENAME  \
# 0                5       AL     01005  ...    31312996  16691442        1
# 1                9       AL     01005  ...   453921144  12363494        2
# 2                9       AL     01005  ...   195878894    586621        1
# 3               GQ       AL     01005  ...   213279789    265574        2
# 4                8       AL     01005  ...   107847361    131426        3
# ...            ...      ...       ...  ...         ...       ...      ...
# 41008            5       WY     56043  ...  3339114066   2555146        3
# 41009            6       WY     56045  ...  4105332203   3640658        2
# 41010           10       WY     56045  ...    40703758         0        1
# 41011            9       WY     56045  ...    10381384         0        2
# 41012            6       WY     56045  ...    59718628    183772        3
#
#                 NAME  FUNCSTAT   INTPTLAT    INTPTLON LSADC  UGA  U7H001
# 0      Block Group 1         S  31.947640  -85.113641    BG  NaN    1589
# 1      Block Group 2         S  32.035353  -85.247768    BG  NaN    1537
# 2      Block Group 1         S  31.952973  -85.400954    BG  NaN     650
# 3      Block Group 2         S  31.933818  -85.540757    BG  NaN    1760
# 4      Block Group 3         S  31.835333  -85.420720    BG  NaN     953
# ...              ...       ...        ...         ...   ...  ...     ...
# 41008  Block Group 3         S  43.840358 -107.411034    BG  NaN     742
# 41009  Block Group 2         S  43.768531 -104.478499    BG  NaN    1990
# 41010  Block Group 1         S  43.881603 -104.257527    BG  NaN    1005
# 41011  Block Group 2         S  43.854118 -104.180737    BG  NaN    1122
# 41012  Block Group 3         S  43.843551 -104.260073    BG  NaN    1375
#
# [41013 rows x 73 columns]

# %%
rural_adi_lm = smf.glm(formula = "access ~ ADI_NATRANK", data=rural_bg_access)
rural_adi_res = rural_adi_lm.fit()
rural_adi_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 access   No. Observations:                39720
# Model:                            GLM   Df Residuals:                    39718
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                          979.25
# Method:                          IRLS   Log-Likelihood:            -1.9313e+05
# Date:                Wed, 10 Apr 2024   Deviance:                   3.8894e+07
# Time:                        00:57:19   Pearson chi2:                 3.89e+07
# No. Iterations:                     3   Pseudo R-squ. (CS):          5.236e-06
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       9.7194      0.568     17.122      0.000       8.607      10.832
# ADI_NATRANK    -0.0035      0.008     -0.456      0.648      -0.018       0.012
# ===============================================================================
# """

# %%
rural_adi_lm2 = smf.glm(formula = "access ~ ADI_NATRANK + AREALAND", data=rural_merged)
rural_adi_res2 = rural_adi_lm2.fit()
rural_adi_res2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 access   No. Observations:                39720
# Model:                            GLM   Df Residuals:                    39717
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                          959.14
# Method:                          IRLS   Log-Likelihood:            -1.9272e+05
# Date:                Sun, 08 Oct 2023   Deviance:                   3.8094e+07
# Time:                        17:14:06   Pearson chi2:                 3.81e+07
# No. Iterations:                     3   Pseudo R-squ. (CS):            0.02078
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       7.6138      0.567     13.440      0.000       6.503       8.724
# ADI_NATRANK     0.0086      0.008      1.137      0.256      -0.006       0.023
# AREALAND     1.068e-08    3.7e-10     28.874      0.000    9.96e-09    1.14e-08
# ===============================================================================
# """
